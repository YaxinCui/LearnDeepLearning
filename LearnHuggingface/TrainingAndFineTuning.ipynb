# %% [markdown]
# ### 展示如何使用任一框架中提供的标准训练工具微调（或从头开始训练）模型。
# ### 还将展示如何使用Trainer()课程。改课程可为您处理培训的复杂性

# %%
# Pytorch中的微调
# from_pretrained()，该库还包括许多特定于任务的最终图层或头

from transformers import BertForSequenceClassification
model = BertForSequenceClassification.from_pretrained('bert-base-uncased')
model.train()
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPretraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
from transformers import AdamW
optimizer = AdamW(model.parameters(), lr=1e-5)
# 可以将权重衰减应用于除偏置和层规范化术语以外的所有参数：

# %%
no_decay = ['bias', 'LayerNorm.weight']
optimizer_grouped_parameters = [
    {'params': [p for n, p in model.named_parameters() if not any(nd in n for nd in no_decay)], 'weight_decay': 0.01},
    {'params': [p for n, p in model.named_parameters() if any(nd in n for nd in no_decay)], 'weight_decay': 0.0}
]
optimizer = AdamW(optimizer_grouped_parameters, lr=1e-5)

# %%
from transformers import BertTokenizer
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
text_batch = ["I love Pixar.", "I don't care for Pixar."]
encoding = tokenizer(text_batch, return_tensors='pt', padding=True, truncation=True)
input_ids = encoding['input_ids']
attention_mask = encoding['attention_mask']

# %%
import torch

labels = torch.tensor([1,0]).unsqueeze(0)
outputs = model(input_ids, attention_mask=attention_mask, labels=labels)
loss = outputs[0]
loss.backward()
optimizer.step()

# %%
labels.size()
# Out:
# torch.Size([1, 2])

# %%
# 也可以自己计算顺势
from torch.nn import functional as F
labels = torch.LongTensor([1,0]).unsqueeze(0)
outputs = model(input_ids, attention_mask=attention_mask)

print(labels)
print(outputs[0])
loss = F.cross_entropy(labels, outputs[0])
loss.backward()
optimizer.step()
# Out:
# tensor([[1, 0]])
# tensor([[-0.3753, -0.6405],
#         [-0.1119, -0.4261]], grad_fn=<AddmmBackward>)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-17-f75ef25eab22> in <module>
#       6 print(labels)
#       7 print(outputs[0])
# ----> 8 loss = F.cross_entropy(labels, outputs[0])
#       9 loss.backward()
#      10 optimizer.step()
#
# ~\Anaconda3\envs\cui\lib\site-packages\torch\nn\functional.py in cross_entropy(input, target, weight, size_average, ignore_index, reduce, reduction)
#    2007     if size_average is not None or reduce is not None:
#    2008         reduction = _Reduction.legacy_get_string(size_average, reduce)
# -> 2009     return nll_loss(log_softmax(input, 1), target, weight, None, ignore_index, None, reduction)
#    2010
#    2011
#
# ...

# %%
from transformers import get_linear_schedule_with_warmup
scheduler = get_linear_schedule_with_warmup(optimizer, num_warmup_steps, num_train_steps)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-8fd7e243bc4d> in <module>
#       1 from transformers import get_linear_schedule_with_warmup
# ----> 2 scheduler = get_linear_schedule_with_warmup(optimizer, num_warmup_steps, num_train_steps)
#
# NameError: name 'num_warmup_steps' is not defined

# %%
loss.backward()
optimizer.step()
scheduler.step()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-20-a254559c8319> in <module>
# ----> 1 loss.backward()
#       2 optimizer.step()
#       3 scheduler.step()
#
# ~\Anaconda3\envs\cui\lib\site-packages\torch\tensor.py in backward(self, gradient, retain_graph, create_graph)
#     164                 products. Defaults to ``False``.
#     165         """
# --> 166         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     167
#     168     def register_hook(self, hook):
#
# ~\Anaconda3\envs\cui\lib\site-packages\torch\autograd\__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      97     Variable._execution_engine.run_backward(
#      98         tensors, grad_tensors, retain_graph, create_graph,
# ---> 99         allow_unreachable=True)  # allow_unreachable flag
#     100
#     101
#
# ...

# %%
for param in model.base_model.parameters():
    param.requires_grad = False

# %%
from sklearn.metrics import precision_recall_fscore_support

def compute_metrics(pred):
    labels = pred.label_ids
    preds = pred.predictions.argmax(-1)
    precision, recall, f1, _ = precision_recall_fscore_support(labels, preds, average='binary')
    acc = accuracy_score(labels, preds)
    return {
        'accuracy': acc,
        'f1': f1,
        'precision': precision,
        'recall': recall
    }
